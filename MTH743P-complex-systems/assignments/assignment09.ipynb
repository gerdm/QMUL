# %% [markdown]
# # Assignment 09
# ## Synchronization of maps

# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1278

# %%
f(x, r) = r * x * (1 - x)
# Out:
# f (generic function with 1 method)

# %%
zn = 0.01
xn = zn
ξn = zn + δξ

xn_hist =Float64[xn]
for _ in 1:100
    xn = f(xn, 4)
    append!(xn_hist, xn)
end

# %%
plot(xn_hist, marker=true, markersize=1, legend=false)
